# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from apyori import apriori

# %%
df = pd.read_csv('china_sectors_greenhouse_association.csv')

# %%
df
# Out:
#       Year         Province/Territory  Latitude  Longitude  \
# 0     2009              New Brunswick     46.57     -66.46
# 1     2009                     Quebec     52.94     -73.55
# 2     2009                    Nunavut     65.29    -119.23
# 3     2009                Nova Scotia     44.68     -63.74
# 4     2009      Northwest Territories     65.29    -119.23
# ...    ...                        ...       ...        ...
# 1009  2009                   Manitoba     53.76     -98.81
# 1010  2009           British Columbia     54.11    -126.56
# 1011  2009                    Ontario     51.25     -85.32
# 1012  2009                     Quebec     52.94     -73.55
# 1013  2009  Newfoundland and Labrador     53.14     -57.66
#
#                          Category            CO2  CH4  N2O
# 0     Oil, gas and transportation            Low  Low  Low
# 1     Oil, gas and transportation            Low  Low  Low
# 2     Oil, gas and transportation            Low  Low  Low
# ...

# %%
df.drop(['Year','Province/Territory','Latitude','Longitude'], axis = 1, inplace=True)

# %%
df
# Out:
#                          Category            CO2  CH4  N2O
# 0     Oil, gas and transportation            Low  Low  Low
# 1     Oil, gas and transportation            Low  Low  Low
# 2     Oil, gas and transportation            Low  Low  Low
# 3     Oil, gas and transportation            Low  Low  Low
# 4           Agricultural & Forest            Low  Low  Low
# ...                           ...            ...  ...  ...
# 1009   Industrial and Residential  Extremely Low  Low  Low
# 1010   Industrial and Residential  Extremely Low  Low  Low
# 1011   Industrial and Residential  Extremely Low  Low  Low
# 1012   Industrial and Residential  Extremely Low  Low  Low
# 1013  Oil, gas and transportation            Low  Low  Low
#
# [1014 rows x 4 columns]

# %%
len(df)
# Out:
# 1014

# %%
num_records = len(df)

records = []  
for i in range(0, num_records):  
    records.append([str(df.values[i,j]) for j in range(0, 4)])

# %%
records
# Out:
# [['Oil, gas and transportation', 'Low', 'Low', 'Low'],
#  ['Oil, gas and transportation', 'Low', 'Low', 'Low'],
#  ['Oil, gas and transportation', 'Low', 'Low', 'Low'],
#  ['Oil, gas and transportation', 'Low', 'Low', 'Low'],
#  ['Agricultural & Forest', 'Low', 'Low', 'Low'],
#  ['Agricultural & Forest', 'Low', 'Low', 'Low'],
#  ['Energy', 'Low', 'Low', 'Low'],
#  ['Energy', 'Low', 'Low', 'Low'],
#  ['Oil, gas and transportation', 'Low', 'Low', 'Low'],
#  ['Industrial and Residential', 'Low', 'Low', 'Low'],
#  ['Oil, gas and transportation', 'Low', 'Low', 'Low'],
#  ['Oil, gas and transportation', 'Low', 'Low', 'Low'],
#  ['Energy', 'Low', 'Low', 'Low'],
#  ['Energy', 'Low', 'Low', 'Low'],
#  ['Oil, gas and transportation', 'Low', 'Low', 'Low'],
#  ['Oil, gas and transportation', 'Low', 'Low', 'Low'],
#  ['Oil, gas and transportation', 'Low', 'Low', 'Low'],
#  ['Oil, gas and transportation', 'Low', 'Low', 'Low'],
#  ['Industrial and Residential', 'Low', 'Low', 'Low'],
# ...

# %%
association_rules = apriori(records, min_support=0.0023, min_confidence=0.10, min_lift=1.5, min_length=2)
association_results = list(association_rules)

# %%
print(len(association_results))
# Out:
# 16

# %%
print(association_results[0])
# Out:
# RelationRecord(items=frozenset({'Energy', 'Extreme'}), support=0.010848126232741617, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Extreme'}), items_add=frozenset({'Energy'}), confidence=0.3055555555555555, lift=2.3833333333333333)])

# %%
results = []
for item in association_results:
    
    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    
    value0 = str(items[0])
    value1 = str(items[1])

    #second index of the inner list
    value2 = str(item[1])[:7]

    #third index of the list located at 0th
    #of the third index of the inner list

    value3 = str(item[2][0][2])[:7]
    value4 = str(item[2][0][3])[:7]
    
    rows = (value0, value1,value2,value3,value4)
    results.append(rows)
    
labels = ['Title 1','Title 2','Support','Confidence','Lift']
movie_suggestion = pd.DataFrame.from_records(results, columns = labels)

print(movie_suggestion)
# Out:
#                         Title 1                      Title 2  Support  \
# 0                        Energy                      Extreme  0.01084
# 1   Oil, gas and transportation                         High  0.04930
# 2                           Low                Extremely Low  0.03944
# 3                           Low                       Energy  0.00887
# 4                        Medium                       Energy  0.00493
# 5                           Low                       Energy  0.00690
# 6    Industrial and Residential                          Low  0.01084
# 7                           Low  Oil, gas and transportation  0.01380
# 8    Industrial and Residential                Extremely Low  0.00986
# 9                        Medium                Extremely Low  0.02761
# 10                          Low  Oil, gas and transportation  0.04930
# 11                       Medium                          Low  0.09861
# ...
